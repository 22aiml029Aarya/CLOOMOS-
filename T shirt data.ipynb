# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_excel(r'Data_set.xlsx')
data
# Out:
#      Sr. no.      Name      Surname  Age  Gender email address  mobile no.  \
# 0          1    Alisha    Singhania   27  Female        abc001   123456789
# 1          2   Sandhya      Iyengar   32  Female        abc002   123456788
# 2          3     Aarav  Chakraborty   33    Male        abc003   123456787
# 3          4   Keerthi        Ghosh   27  Female        abc004   123456786
# 4          5    Khushi        Arora   34  Female        abc005   123456785
# ..       ...       ...          ...  ...     ...           ...         ...
# 495      496  Himanshu    Mukherjee   48    Male        abc496   123456294
# 496      497   Devansh  Chakraborty   22    Male        abc497   123456293
# 497      498   Gayatri        Batra   24  Female        abc498   123456292
# 498      499     Rupal        Desai   26  Female        abc499   123456291
# 499      500    Indira        Yadav   44  Female        abc500   123456290
#
#      Location Type of t-shirt   Color  Price  Ratings  \
# 0    Kolhapur          V Neck  Purple   1500        1
# 1      Indore    Cuban Collar    Blue    300        2
# 2      Mumbai           Denim    Blue   1000        5
# 3      Indore      Muscle Fit  Yellow    600        5
# 4      Mumbai      Muscle Fit    Blue   1500        5
# ..        ...             ...     ...    ...      ...
# 495      Pune            Polo     Red    350        4
# 496   Solapur     Long Sleeve  Orange    800        4
# 497    Bhopal           Denim  Purple    350        5
# 498    Rajkot          V Neck   White    300        4
# 499    Mumbai           Denim  Orange   1000        1
#
#                                   Description        Date
# 0    Moisture-wicking performance workout tee   12/4/2021
# 1                   Classic fit crew neck tee   23/7/2020
# 2           Sleek, solid-color minimalist tee    6/3/2020
# 3                   Classic fit crew neck tee    9/8/2022
# 4      Premium blend T-shirt, multiple colors  28/12/2020
# ..                                        ...         ...
# 495  Moisture-wicking performance workout tee   20/9/2022
# 496  Moisture-wicking performance workout tee   27/5/2020
# 497          Bold, vibrant T-shirt, stand out   27/3/2022
# 498          Bold, vibrant T-shirt, stand out   2/10/2020
# 499    Vintage-inspired super-soft fabric tee   5/11/2021
#
# [500 rows x 14 columns]

# %%
data.head()
# Out:
#    Sr. no.     Name      Surname  Age  Gender email address  mobile no.  \
# 0        1   Alisha    Singhania   27  Female        abc001   123456789
# 1        2  Sandhya      Iyengar   32  Female        abc002   123456788
# 2        3    Aarav  Chakraborty   33    Male        abc003   123456787
# 3        4  Keerthi        Ghosh   27  Female        abc004   123456786
# 4        5   Khushi        Arora   34  Female        abc005   123456785
#
#    Location Type of t-shirt   Color  Price  Ratings  \
# 0  Kolhapur          V Neck  Purple   1500        1
# 1    Indore    Cuban Collar    Blue    300        2
# 2    Mumbai           Denim    Blue   1000        5
# 3    Indore      Muscle Fit  Yellow    600        5
# 4    Mumbai      Muscle Fit    Blue   1500        5
#
#                                 Description        Date
# 0  Moisture-wicking performance workout tee   12/4/2021
# 1                 Classic fit crew neck tee   23/7/2020
# 2         Sleek, solid-color minimalist tee    6/3/2020
# 3                 Classic fit crew neck tee    9/8/2022
# 4    Premium blend T-shirt, multiple colors  28/12/2020

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sr. no.          500 non-null    int64
#  1   Name             500 non-null    object
#  2   Surname          500 non-null    object
#  3   Age              500 non-null    int64
#  4   Gender           500 non-null    object
#  5   email address    500 non-null    object
#  6   mobile no.       500 non-null    int64
#  7   Location         500 non-null    object
#  8   Type of t-shirt  500 non-null    object
#  9   Color            500 non-null    object
#  10  Price            500 non-null    int64
#  11  Ratings          500 non-null    int64
#  12  Description      500 non-null    object
#  13  Date             500 non-null    object
# dtypes: int64(5), object(9)
# memory usage: 54.8+ KB

# %%
data.describe(include='all')
# Out:
#            Sr. no.     Name Surname         Age  Gender email address  \
# count   500.000000      500     500  500.000000     500           500
# unique         NaN      180     138         NaN       2           500
# top            NaN  Gayatri     Das         NaN  Female        abc001
# freq           NaN       10      28         NaN     262             1
# mean    250.500000      NaN     NaN   32.922000     NaN           NaN
# std     144.481833      NaN     NaN   10.149973     NaN           NaN
# min       1.000000      NaN     NaN   15.000000     NaN           NaN
# 25%     125.750000      NaN     NaN   24.000000     NaN           NaN
# 50%     250.500000      NaN     NaN   34.000000     NaN           NaN
# 75%     375.250000      NaN     NaN   42.000000     NaN           NaN
# max     500.000000      NaN     NaN   50.000000     NaN           NaN
#
#           mobile no. Location Type of t-shirt  Color        Price     Ratings  \
# count   5.000000e+02      500             500    500   500.000000  500.000000
# unique           NaN       15              10      7          NaN         NaN
# top              NaN   Nashik     Long Sleeve  Black          NaN         NaN
# freq             NaN       45              60     81          NaN         NaN
# mean    1.234565e+08      NaN             NaN    NaN   696.000000    3.086000
# std     1.444818e+02      NaN             NaN    NaN   387.083541    1.477488
# min     1.234563e+08      NaN             NaN    NaN   300.000000    1.000000
# 25%     1.234564e+08      NaN             NaN    NaN   350.000000    2.000000
# 50%     1.234565e+08      NaN             NaN    NaN   600.000000    3.000000
# 75%     1.234567e+08      NaN             NaN    NaN  1000.000000    4.000000
# max     1.234568e+08      NaN             NaN    NaN  1500.000000    5.000000
#
#                                    Description       Date
# count                                      500        500
# unique                                      10        422
# top     Premium blend T-shirt, multiple colors  15/9/2023
# freq                                        65          3
# mean                                       NaN        NaN
# std                                        NaN        NaN
# min                                        NaN        NaN
# 25%                                        NaN        NaN
# 50%                                        NaN        NaN
# 75%                                        NaN        NaN
# max                                        NaN        NaN

# %%
data = data.dropna()

# %%
data = data.drop_duplicates()

# %%
data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 data['Date'] = pd.to_datetime(data['Date'], format='%d/%m/%Y')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:1050, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1048         result = arg.map(cache_array)
#    1049     else:
# -> 1050         values = convert_listlike(arg._values, format)
#    1051         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1052 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:453, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     451 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     452 if format is not None and format != "mixed":
# --> 453     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     455 result, tz_parsed = objects_to_datetime64ns(
#     456     arg,
#     457     dayfirst=dayfirst,
#    (...)
#     461     allow_object=True,
#     462 )
#     464 if tz_parsed is not None:
#     465     # We can take a shortcut since the datetime64 numpy array
#     466     # is in UTC
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:484, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     473 def _array_strptime_with_fallback(
#     474     arg,
#     475     name,
#    (...)
#     479     errors: str,
#     480 ) -> Index:
#     481     """
#     482     Call array_strptime, with fallback behavior depending on 'errors'.
#     483     """
# --> 484     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     485     if any(tz is not None for tz in timezones):
#     486         return _return_parsed_timezone_results(result, timezones, utc, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:530, in pandas._libs.tslibs.strptime.array_strptime()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\tslibs\strptime.pyx:489, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: day is out of range for month, at position 215. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
sns.histplot(data['Age'], bins=10)
plt.show()

# %%
sns.countplot(x='Gender', data=data)
plt.show()

# %%
sns.boxplot(x='Type of t-shirt', y='Price', hue='Color', data=data)
plt.show()

# %%
sns.histplot(data['Ratings'], bins=10)
plt.show()

# %%
print(data.describe())
# Out:
#           Sr. no.         Age    mobile no.        Price     Ratings
# count  500.000000  500.000000  5.000000e+02   500.000000  500.000000
# mean   250.500000   32.922000  1.234565e+08   696.000000    3.086000
# std    144.481833   10.149973  1.444818e+02   387.083541    1.477488
# min      1.000000   15.000000  1.234563e+08   300.000000    1.000000
# 25%    125.750000   24.000000  1.234564e+08   350.000000    2.000000
# 50%    250.500000   34.000000  1.234565e+08   600.000000    3.000000
# 75%    375.250000   42.000000  1.234567e+08  1000.000000    4.000000
# max    500.000000   50.000000  1.234568e+08  1500.000000    5.000000

# %%
print(data['Gender'].value_counts())
# Out:
# Gender
# Female    262
# Male      238
# Name: count, dtype: int64

# %%
print(data['Type of t-shirt'].value_counts())
# Out:
# Type of t-shirt
# Long Sleeve     60
# Crew Neck       59
# Cuban Collar    57
# Scoop Neck      55
# Polo            54
# Sleeveless      46
# Muscle Fit      45
# V Neck          43
# Denim           43
# Short Sleeve    38
# Name: count, dtype: int64

# %%
corr = data.corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 corr = data.corr()
#       2 sns.heatmap(corr, annot=True, cmap='coolwarm')
#       3 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Alisha'
